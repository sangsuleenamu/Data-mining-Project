# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import re

from konlpy.tag import Okt
from konlpy.tag import Hannanum
from collections import Counter
# !pip install stylecloud
# Out:
# Collecting stylecloud
#   Downloading stylecloud-0.5.2.tar.gz (262 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: wordcloud in c:\users\a1025\appdata\local\programs\python\python38\lib\site-packages (from stylecloud) (1.8.1)
# Collecting icon-font-to-png
#   Downloading icon_font_to_png-0.4.1-py2.py3-none-any.whl (161 kB)
# Collecting palettable
#   Downloading palettable-3.3.0-py2.py3-none-any.whl (111 kB)
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: matplotlib in c:\users\a1025\appdata\local\programs\python\python38\lib\site-packages (from stylecloud) (3.5.1)
# Requirement already satisfied: six in c:\users\a1025\appdata\local\programs\python\python38\lib\site-packages (from fire->stylecloud) (1.16.0)
# Collecting termcolor
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: Pillow>=4.0.0 in c:\users\a1025\appdata\local\programs\python\python38\lib\site-packages (from icon-font-to-png->stylecloud) (8.4.0)
# Collecting tinycss>=0.4
#   Downloading tinycss-0.4.tar.gz (87 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests>=2.12.5 in c:\users\a1025\appdata\local\programs\python\python38\lib\site-packages (from icon-font-to-png->stylecloud) (2.26.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\a1025\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->stylecloud) (4.28.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\a1025\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->stylecloud) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\a1025\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->stylecloud) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\a1025\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->stylecloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\a1025\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->stylecloud) (3.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\a1025\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->stylecloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\a1025\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->stylecloud) (0.11.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\a1025\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (2.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\a1025\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\a1025\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\a1025\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (1.26.7)
# Using legacy 'setup.py install' for stylecloud, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for fire, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for tinycss, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for termcolor, since package 'wheel' is not installed.
# Installing collected packages: tinycss, termcolor, palettable, icon-font-to-png, fire, stylecloud
#     Running setup.py install for tinycss: started
#     Running setup.py install for tinycss: finished with status 'done'
#     Running setup.py install for termcolor: started
#     Running setup.py install for termcolor: finished with status 'done'
#     Running setup.py install for fire: started
#     Running setup.py install for fire: finished with status 'done'
#     Running setup.py install for stylecloud: started
#     Running setup.py install for stylecloud: finished with status 'done'
# Successfully installed fire-0.4.0 icon-font-to-png-0.4.1 palettable-3.3.0 stylecloud-0.5.2 termcolor-1.1.0 tinycss-0.4

# %%
##lyric data open
with open('ballad.txt', 'r',encoding='UTF8') as f2:
    result = f2.read()
    
okt = Okt()
noun = okt.nouns(result)

nouns = [n for n in noun if len(n)>1]
count = Counter(nouns)
tags = count.most_common(100)

mask = Image.new("RGBA", image.size, (255,255,255)) #(2555,2575)는 사진 크기, (255,255,255)는 색을의미
image = Image.open('BB.png').convert("RGBA")
x,y = image.size
mask.paste(image,(0,0,x,y),image)
mask = np.array(mask)

from wordcloud import WordCloud
wordcould = WordCloud(font_path='C:\Windows\Fonts\gulim.ttc', background_color='white', mask=mask).generate_from_frequencies(dict(tags))

fig = plt.figure()
plt.axis('off')
plt.imshow(wordcould)

tags
# Out:
# [('사랑', 2869),
#  ('그대', 1925),
#  ('우리', 1798),
#  ('마음', 1169),
#  ('시간', 1101),
#  ('다시', 959),
#  ('기억', 836),
#  ('오늘', 799),
#  ('생각', 734),
#  ('이제', 706),
#  ('하루', 600),
#  ('사람', 588),
#  ('모든', 551),
#  ('지금', 533),
#  ('순간', 527),
#  ('모습', 520),
#  ('눈물', 519),
#  ('하나', 512),
#  ('세상', 478),
#  ('추억', 473),
#  ('바람', 454),
#  ('그때', 429),
#  ('이별', 384),
#  ('혼자', 373),
#  ('우린', 360),
#  ('모두', 351),
#  ('보고', 350),
#  ('매일', 328),
#  ('하늘', 306),
#  ('서로', 296),
#  ('노래', 292),
#  ('그날', 283),
#  ('정말', 272),
#  ('당신', 272),
#  ('아무', 270),
#  ('조금', 263),
#  ('가슴', 258),
#  ('여기', 255),
#  ('미소', 254),
#  ('처음', 249),
#  ('거리', 246),
#  ('항상', 242),
#  ('어디', 231),
#  ('그냥', 228),
#  ('계절', 205),
#  ('언제', 205),
#  ('멀리', 203),
#  ('남아', 200),
#  ('해도', 190),
#  ('바보', 190),
#  ('마지막', 188),
#  ('잠시', 186),
#  ('자꾸', 185),
#  ('걸음', 182),
#  ('내일', 181),
#  ('가득', 179),
#  ('위해', 179),
#  ('다른', 178),
#  ('후회', 178),
#  ('한번', 178),
#  ('누구', 176),
#  ('나나', 176),
#  ('혹시', 169),
#  ('안녕', 166),
#  ('자리', 160),
#  ('가끔', 157),
#  ('겨울', 157),
#  ('잡고', 151),
#  ('위로', 150),
#  ('햇살', 148),
#  ('그대로', 147),
#  ('선물', 145),
#  ('수가', 144),
#  ('이름', 142),
#  ('마주', 142),
#  ('상처', 141),
#  ('사이', 140),
#  ('소리', 139),
#  ('얼굴', 136),
#  ('전부', 136),
#  ('점점', 136),
#  ('약속', 134),
#  ('얘기', 131),
#  ('지나', 129),
#  ('눈빛', 128),
#  ('행복', 128),
#  ('계속', 126),
#  ('가장', 122),
#  ('이야기', 120),
#  ('시작', 118),
#  ('얼마나', 117),
#  ('어제', 116),
#  ('우릴', 116),
#  ('목소리', 115),
#  ('그땐', 115),
#  ('홀로', 114),
#  ('만날', 114),
#  ('아침', 114),
#  ('진심', 113),
#  ('무엇', 112)]

# %%
##lyric data open
with open('hiphop.txt', 'r',encoding='UTF8') as f2:
    result = f2.read()
    
okt = Okt()
noun = okt.nouns(result)

nouns = [n for n in noun if len(n)>1]
count = Counter(nouns)
tags = count.most_common(100)

mask = Image.new("RGBA",(2555,2575), (255,255,255)) #(2555,2575)는 사진 크기, (255,255,255)는 색을의미
image = Image.open('HH.png').convert("RGBA")
x,y = image.size
mask.paste(image,(0,0,x,y),image)
mask = np.array(mask)

from wordcloud import WordCloud
wordcould = WordCloud(font_path='C:\Windows\Fonts\gulim.ttc', background_color='white', width=2000, height=1600, mask=mask).generate_from_frequencies(dict(tags))

fig = plt.figure()
plt.axis('off')
plt.imshow(wordcould)

tags
# Out:
# [('우리', 440),
#  ('시간', 394),
#  ('이제', 354),
#  ('다시', 339),
#  ('생각', 301),
#  ('우린', 282),
#  ('지금', 266),
#  ('오늘', 262),
#  ('사랑', 250),
#  ('매일', 234),
#  ('전부', 217),
#  ('사람', 215),
#  ('하나', 196),
#  ('그냥', 186),
#  ('기억', 178),
#  ('계속', 178),
#  ('내일', 165),
#  ('어디', 164),
#  ('모두', 160),
#  ('혼자', 152),
#  ('여기', 147),
#  ('그때', 143),
#  ('마음', 135),
#  ('머리', 132),
#  ('다른', 131),
#  ('멀리', 130),
#  ('세상', 122),
#  ('노래', 120),
#  ('위해', 118),
#  ('기분', 118),
#  ('하루', 115),
#  ('모든', 111),
#  ('다음', 109),
#  ('위로', 102),
#  ('보고', 100),
#  ('마치', 100),
#  ('모습', 99),
#  ('항상', 97),
#  ('이건', 94),
#  ('하늘', 94),
#  ('절대', 89),
#  ('인생', 89),
#  ('아무', 89),
#  ('소리', 89),
#  ('진짜', 86),
#  ('친구', 83),
#  ('순간', 83),
#  ('그게', 78),
#  ('음악', 77),
#  ('눈물', 77),
#  ('시작', 75),
#  ('반복', 74),
#  ('정신', 73),
#  ('굳이', 71),
#  ('누가', 71),
#  ('나이', 70),
#  ('바람', 68),
#  ('거리', 68),
#  ('아침', 67),
#  ('조금', 67),
#  ('그녀', 66),
#  ('한번', 64),
#  ('누구', 64),
#  ('서로', 63),
#  ('가끔', 63),
#  ('해도', 63),
#  ('저기', 61),
#  ('가지', 60),
#  ('새끼', 60),
#  ('추억', 59),
#  ('제발', 58),
#  ('성공', 58),
#  ('고민', 58),
#  ('마지막', 58),
#  ('이유', 57),
#  ('걱정', 57),
#  ('후회', 57),
#  ('어제', 57),
#  ('거기', 56),
#  ('필요', 55),
#  ('준비', 54),
#  ('문제', 54),
#  ('사이', 53),
#  ('이상', 52),
#  ('감정', 52),
#  ('사실', 52),
#  ('높이', 52),
#  ('처음', 51),
#  ('의미', 50),
#  ('이해', 49),
#  ('자리', 49),
#  ('엄마', 49),
#  ('처럼', 49),
#  ('거짓말', 49),
#  ('아마', 48),
#  ('가사', 48),
#  ('바보', 48),
#  ('수가', 48),
#  ('자신', 47),
#  ('자꾸', 47)]
